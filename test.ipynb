# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
#File path with glob

# %%
path = "C:/Users/Asus/OneDrive - KMITL/Desktop/PTT/"
all_files = glob.glob(path+"*.csv")
all_files
# Out:
# ['C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-24-หุ้นPTT.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-25-หุ้นPTT.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-hr1.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-hr2.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-hr3.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-hr4.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-min1.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-min15.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-min3.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-min30.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-min45.csv',
# ...

# %%
daily_file = []
for i in all_files:
    if "daily" in i:
        daily_file.append(i)

daily_file
# Out:
# ['C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-27-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-28-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-04-29-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-04-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-05-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-06-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-07-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-08-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-09-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-10-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-11-หุ้นPTT-daily.csv',
#  'C:/Users/Asus/OneDrive - KMITL/Desktop/PTT\\2023-05-12-หุ้นPTT-daily.csv',
# ...

# %%
li = []
for filename in all_files:
    df = pd.read_csv(filename,index_col=None,header=0)
    li.append(df)
li[1]
df = pd.concat(li,axis=0,ignore_index=True)
df
# Out:
#                    datetime   symbol   open   high    low  close       volume
# 0       2023-04-19 11:15:00  SET:PTT  31.50  31.50  31.50  31.50       5300.0
# 1       2023-04-19 11:16:00  SET:PTT  31.50  31.50  31.25  31.50      15100.0
# 2       2023-04-19 11:17:00  SET:PTT  31.25  31.50  31.25  31.50      25700.0
# 3       2023-04-19 11:18:00  SET:PTT  31.50  31.50  31.50  31.50       3900.0
# 4       2023-04-19 11:19:00  SET:PTT  31.50  31.50  31.25  31.25      12100.0
# ...                     ...      ...    ...    ...    ...    ...          ...
# 952540  2023-07-03 09:00:00  SET:PTT  33.75  34.00  33.25  33.75  211440850.0
# 952541  2023-07-10 09:00:00  SET:PTT  33.75  35.00  33.50  35.00  250344125.0
# 952542  2023-07-17 09:00:00  SET:PTT  35.00  35.00  34.00  34.75  305046963.0
# 952543  2023-07-24 09:00:00  SET:PTT  34.75  35.25  34.50  34.75  202111577.0
# 952544  2023-07-31 09:00:00  SET:PTT  34.75  35.00  34.50  35.00   29386167.0
#
# [952545 rows x 7 columns]

# %%
li2 = []
for filename in daily_file:
    df = pd.read_csv(filename,index_col=None,header=0)
    li2.append(df)
li2[1]
df2 = pd.concat(li2,axis=0,ignore_index=True)
df2
# Out:
#                   datetime   symbol   open   high    low  close      volume
# 0      2019-03-12 09:00:00  SET:PTT  47.50  47.75  47.25  47.25  34074500.0
# 1      2019-03-13 09:00:00  SET:PTT  47.25  47.75  46.75  47.75  50919200.0
# 2      2019-03-14 09:00:00  SET:PTT  48.00  48.50  47.75  48.00  47689700.0
# 3      2019-03-15 09:00:00  SET:PTT  48.25  48.50  47.75  48.25  67054000.0
# 4      2019-03-18 09:00:00  SET:PTT  48.25  48.50  47.50  47.75  50421000.0
# ...                    ...      ...    ...    ...    ...    ...         ...
# 77995  2023-07-24 09:00:00  SET:PTT  34.75  35.00  34.50  34.50  44322848.0
# 77996  2023-07-25 09:00:00  SET:PTT  34.75  35.00  34.50  35.00  33119720.0
# 77997  2023-07-26 09:00:00  SET:PTT  34.75  35.00  34.50  35.00  35394763.0
# 77998  2023-07-27 09:00:00  SET:PTT  34.75  35.25  34.50  34.75  89274246.0
# 77999  2023-07-31 09:00:00  SET:PTT  34.75  35.00  34.50  35.00  29386167.0
#
# [78000 rows x 7 columns]

# %%
new_daily = df2.drop_duplicates()

new_daily
# Out:
#                   datetime   symbol   open   high    low  close      volume
# 0      2019-03-12 09:00:00  SET:PTT  47.50  47.75  47.25  47.25  34074500.0
# 1      2019-03-13 09:00:00  SET:PTT  47.25  47.75  46.75  47.75  50919200.0
# 2      2019-03-14 09:00:00  SET:PTT  48.00  48.50  47.75  48.00  47689700.0
# 3      2019-03-15 09:00:00  SET:PTT  48.25  48.50  47.75  48.25  67054000.0
# 4      2019-03-18 09:00:00  SET:PTT  48.25  48.50  47.50  47.75  50421000.0
# ...                    ...      ...    ...    ...    ...    ...         ...
# 68938  2019-03-08 09:00:00  SET:PTT  47.75  48.00  47.25  47.50  42416300.0
# 68939  2019-03-11 09:00:00  SET:PTT  47.50  48.00  47.25  47.25  34589700.0
# 69999  2023-07-26 09:00:00  SET:PTT  34.75  35.00  34.50  35.00  35394763.0
# 71999  2023-07-27 09:00:00  SET:PTT  34.75  35.25  34.50  34.75  89274246.0
# 77999  2023-07-31 09:00:00  SET:PTT  34.75  35.00  34.50  35.00  29386167.0
#
# [2004 rows x 7 columns]

# %% [markdown]
# data1 = pd.read_csv("/content/2023-04-24-หุ้นPTT.csv",sep=",")
# data2 = pd.read_csv("/content/2023-04-25-หุ้นPTT.csv",sep=",")
# new_data = data1.drop_duplicates()
